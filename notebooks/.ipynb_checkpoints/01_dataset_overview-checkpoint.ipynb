# %% [markdown]
# # 01 - Dataset Overview
#
# **Goal:** trust the dataset before training anything.
#
# This notebook computes class distribution, samples per class, and frame counts per video for the training/validation splits. Use it to catch:
# - class imbalance,
# - missing or empty video folders,
# - suspicious frame-count outliers.
#
# All logic comes from `smth2smth.shared.data`; this notebook only consumes it.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

REPO_ROOT = Path.cwd().parent
SRC_DIR = REPO_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from smth2smth.shared.data import collect_video_samples

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# %%
TRAIN_DIR = REPO_ROOT / "data" / "train"
VAL_DIR = REPO_ROOT / "data" / "val"

samples_train = collect_video_samples(TRAIN_DIR)
samples_val = collect_video_samples(VAL_DIR)

df_train = pd.DataFrame(samples_train, columns=["video_dir", "label"])
df_val = pd.DataFrame(samples_val, columns=["video_dir", "label"])

print(f"train videos: {len(df_train)}")
print(f"val   videos: {len(df_val)}")
df_train.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 TRAIN_DIR = REPO_ROOT / "processed_data" / "train"
#       2 VAL_DIR = REPO_ROOT / "processed_data" / "val"
#       3
# ----> 4 samples_train = collect_video_samples(TRAIN_DIR)
#       5 samples_val = collect_video_samples(VAL_DIR)
#       6
#       7 df_train = pd.DataFrame(samples_train, columns=["video_dir", "label"])
#
# File /Data/romain.poggi/Modal/project/smth2smth/src/smth2smth/shared/data/video_dataset.py:94, in collect_video_samples(root_dir)
#      92 root_dir = root_dir.resolve()
#      93 if not root_dir.is_dir():
# ---> 94     raise FileNotFoundError(f"Dataset root not found: {root_dir}")
#      96 samples: List[VideoSample] = []
#      97 class_dirs = [p for p in sorted(root_dir.iterdir()) if p.is_dir()]
#
# FileNotFoundError: Dataset root not found: /Data/romain.poggi/Modal/project/smth2smth/processed_data/train

# %% [markdown]
# ## Class distribution
#
# Look for severe imbalance or missing classes.

# %%
counts = df_train["label"].value_counts().sort_index()
fig, ax = plt.subplots(figsize=(12, 4))
counts.plot.bar(ax=ax)
ax.set_title("Train videos per class")
ax.set_xlabel("class index")
ax.set_ylabel("count")
plt.tight_layout()

# %% [markdown]
# ## Frames per video
#
# Detects videos that are too short (sampling will repeat frames) or unusually long.

# %%
def frame_count(video_dir: Path) -> int:
    return sum(1 for _ in video_dir.glob("*.jpg"))

df_train["n_frames"] = df_train["video_dir"].map(frame_count)
df_train["n_frames"].describe()
